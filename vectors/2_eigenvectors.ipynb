# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import Normalize

# %%
# %load_ext autoreload
# %autoreload 2
from utils.plots import plot_vectors_3d, plot_2d_arrow, plot_2d_line, plot_2d_arrow_color
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
A = np.array([[1,0],
             [1,3]])
A
# Out:
# array([[1, 0],
#        [1, 3]])

# %%
np.diag(A)
# Out:
# array([1, 3])

# %%
np.diag(np.diag(A))
# Out:
# array([[1, 0],
#        [0, 3]])

# %%
l, vecs = np.linalg.eig(A)
vecs.shape
# Out:
# (2, 2)

# %%
D = np.diag(l)
D
# Out:
# array([[3., 0.],
#        [0., 1.]])

# %%
Q = vecs
Q
# Out:
# array([[ 0.        ,  0.89442719],
#        [ 1.        , -0.4472136 ]])

# %%
Q@D@np.linalg.inv(Q)
# Out:
# array([[1., 0.],
#        [1., 3.]])

# %%
A@Q[:,0]
# Out:
# array([0., 3.])

# %%
Q[:,0]*l[0]
# Out:
# array([0., 3.])

# %%
A@Q[:,1]
# Out:
# array([ 0.89442719, -0.4472136 ])

# %%
Q[:,1]*l[1]
# Out:
# array([ 0.89442719, -0.4472136 ])

# %%
plot_2d_line(vecs, origin=[0,0])

# %%
origin = [0,0]
plot_2d_arrow(vecs, origin=origin,)

# %%
plot_2d_arrow_color(vecs)

# %%
myvecs = np.array([[0,1],
                 [1,0],
                 [0.5, 0.5]])
myvecs
# Out:
# array([[0. , 1. ],
#        [1. , 0. ],
#        [0.5, 0.5]])

# %%
plot_2d_line(myvecs)

# %%
plot_2d_arrow(myvecs)

# %%
plot_2d_arrow_color(myvecs)
